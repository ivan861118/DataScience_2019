# %%
# %matplotlib inline
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

data=[]
names = []##col names
total =0
# 開啟 CSV 檔案
with open('claim.csv', newline='') as csv_file:
        df = pd.read_csv(csv_file)
        names = list(df.columns.values)
        df.fillna(0, inplace=True)
    ##處理 ILLNESS_CD 出現0的問題\n",
        df=df[(df[names[4]]!=0)]
        print(names)
    ##total
        for i in df['CASE_NO']:
            total+=1
        print(total)
# Out:
# ['CASE_NO', 'INSURED_SEX', 'AGE_RANK', 'TENURE', 'ILLNESS_CD', 'illness_code_desc', 'HOSP_CD', 'hospital_name', 'REIMB_AMT_K', 'settle_dt', 'CountNo', 'REIMB_AMT_5Y_K', 'RECENCY_YEAR', 'CountCovNo', 'Sum_afyp_K', 'EFFECTdate', 'TYPE_CODE', 'AFYP_K']
# 107599

# %%
ILLNESS_CD_CTG = []
ILLNESS_CTG = []

for item in df["ILLNESS_CD"]:
        if item not in ILLNESS_CD_CTG :
            ILLNESS_CD_CTG.append(item)
        
for item in df["illness_code_desc"]:
    if item not in ILLNESS_CTG :
        ILLNESS_CTG.append(item)

print("Num of illness = ")
print(ILLNESS_CTG)
print(len(ILLNESS_CD_CTG))
# Out:
# Num of illness =
# ['橈骨骨折', '冠狀動脈疾病', '腦中風', '攝護腺（前列腺）疾病（發炎,肥大等）', '腕及手之脫臼，扭，拉，挫，捩傷', '牙周病', '皮膚良性腫瘤', '糖尿病', '尿道/輸尿管結石', '痔瘡', '直腸息肉/大腸息肉/結腸息肉', '鼻咽癌', '其他骨骼肌肉結締組織疾病', '其他', '胃惡性腫瘤', '大腸/直腸惡性腫瘤', '胃潰瘍', '胰惡性腫瘤', '攝護腺（前列腺）之惡性腫瘤', '腹腔疝氣（腹股溝疝氣及其他）', '腰及背部之脫臼，扭，拉，挫，捩傷', '膀胱惡性腫瘤', '肺炎', '帕金森氏症', '視網膜病變,剝離', '下肢', '肩及上臂之脫臼，扭，拉，挫，捩傷', '踝及足之脫臼，扭，拉，挫，捩傷', '腦及神經系統良性腫瘤', '牙及其支持組織之疾病', '膝及小腿之脫臼，扭，拉，挫，捩傷', '頭部其他部位外傷', '其他耳及乳突之疾病', '足部外傷', '慢性阻塞性肺疾病', '肝癌', '白內障', '消化系統良性腫瘤', '心悸', '其他腦血管疾病', '其他頸椎,脊椎病變', '舌癌', '肺癌', '腎結石', '韌帶損傷,斷裂', '眩暈，頭痛', '腎衰竭', '二尖瓣,三尖瓣疾病（狹窄,閉鎖不全,脫垂）', '肝硬化', '腎臟惡性腫瘤', '肝膿瘍', '掌骨骨折（含指骨）', '股骨頸骨折', '口腔白斑症', '中耳炎及乳突炎', '白血病', '椎間板脫（突）出症,壓迫症(含根神經)', '其他部位外傷', '手之外傷', '骨骼，關節及軟骨之良性腫瘤', '其他腸道惡性腫瘤', '脛骨骨折', '其他部位之脫臼，扭，拉，挫，捩傷', '腦惡性腫瘤', '膽結石', '蹠骨骨折（含趾骨）', '胸部之脫臼，扭，拉，挫，捩傷', '甲狀腺疾患', '腸阻塞（包括扭轉,嵌入）', '鎖骨，肩胛骨骨折', '泌尿道感染', '支氣管肺炎', '黃斑部病變', '肌腱斷裂', '其他內分泌及代謝之疾病', '腹膜炎', '其他部位良性腫瘤', '食道惡性腫瘤', '腎水腫', '靜脈曲張', '肺結核病', '其他消化器及腹膜之惡性腫瘤', '顱內出血', '膝及小腿之外傷', '膽囊炎/膽管炎', '呼吸道及胸腔內器官之良性腫瘤', '肘及前臂之脫臼，扭，拉，挫，捩傷', '高血壓', '動脈，小動脈及微血管之其他疾病', '其他精神疾患', '胸,腹腔及骨盆內組織器官損（內）傷', '肋（胸）骨骨折', '呼吸衰竭', '其他泌尿生殖器官惡性腫瘤', '皮膚之惡性腫瘤', '骨頭缺血性壞死', '暈厥及昏迷', '脊椎分離（解離）症,滑脫（脫出）症', '臉骨骨折（鼻骨，眶骨，顴骨，頜骨等）', '慢性腎臟病', '脊椎（背椎，腰椎，薦椎，胸椎）骨折', '肘及前臂之外傷', '心臟性節律不整', '心臟（心肺）衰竭', '肺膿瘍，膿胸', '口腔癌', '大腦內或顱內出血', '頭及頸部之脫臼，扭，拉，挫，捩傷', '痛風', '關節炎', '心肌梗塞', '蜂窩組織炎', '十二指腸潰瘍（含出血及穿孔）', '急性支氣管炎', '原位癌', '肌肉，肌膜，肌腱發炎', '其他心臟疾病及併發症', '腸胃炎（胃,小腸,大腸,十二指腸）', '腦震盪', '闌尾炎', '乳房之惡性腫瘤', '其他胃疾', '黃疸', '股骨骨折', '消化性潰瘍（含出血及穿孔）', '其他及未明示位置（除腦部外）之惡性腫瘤', '肛門廔管', '其他上呼吸道疾病', '其他膽病變', '甲狀腺癌', '敗血症，菌血症', '發（高）燒', '腓骨骨折', '其他肝病變', '角膜病變（發炎,水腫,糜爛）', '乳腺炎', '上肢', '聲帶結節/聲帶息肉/聲帶囊腫', '甲溝炎', '貧血', '腎炎', '淋巴及造血組織之惡性腫瘤', '其他神經系統疾病', '骨及軟骨之惡性腫瘤', '膝蓋骨（髕骨）骨折', '支氣管擴張症', '胰臟疾病', '慢性肝炎（含酒精性肝炎）', '食道疾病（發炎,潰瘍,狹窄,穿孔,憩室等）', '髖及大腿之脫臼，扭，拉，挫，捩傷', '高血壓性心臟病', '鼻炎', '過敏性鼻炎', '踝骨，跟骨，距骨骨折', '脊柱神經損傷', '急性脊髓灰白質炎（小兒麻痺）', '疣，癤', '腰痛，背痛', '肛門（直腸）膿瘍/肛裂', '心絞痛，狹心症', '休克', '其他腰，背疾患', '其他腺體癌', '主動脈瓣疾病（狹窄,閉鎖不全）', '氣管，支氣管之惡性腫瘤', '肱骨骨折', '腕骨骨折', '其他功能性消化道障礙及疾患', '心肌病變', '牙齒斷裂', '男性生殖器官良性腫瘤', '精索靜脈曲張', '其他消化系統之疾病', '腦膜炎', '腕部神經壓迫症', '蕁麻疹', '其他呼吸及胸內器官之惡性腫瘤', '蛋白尿', '動脈栓塞及血栓症', '其他腎病變', '動脈硬化性心臟病', '鋼釘拔除（註:請先鍵入事故原因及受傷部位）', '軀幹', '顏面神經麻庳', '尿毒症', '半月板損傷', '軟骨損傷，軟化', '流行性感冒', '鼻竇炎', '鼻中膈彎曲及鼻息肉', '肺部及呼吸系統之其他疾病', '傷口感染', '耳聾', '眼球外傷', '其他泌尿系統之疾病', '唇，口腔及咽之良性腫瘤', '骨盆（髖骨，恥骨）骨折', '腕之外傷', '手掌，手指截斷傷', '口腔軟組織疾病', '精神分裂症', '免疫疾病', '其他男性生殖器官疾病', '腹瀉，腹痛', '急性肝炎', '過敏性紫斑', '癲癇', '肩及上臂之外傷', '喉惡性腫瘤', '心內膜炎', '動脈粥樣硬化', '其他眼及其附屬器官之疾患', '包皮過長，包莖及包皮發炎', '靜脈炎，靜脈栓塞及血栓', '急性扁桃腺炎', '性病（含肛門溼疣、淋病等，980327(含)前結案含梅毒性病）', '神經痛', '尺骨骨折', '甲狀腺之良性腫瘤', '酒癮徵候群', '缺血性心臟病', '膽脂瘤', '雞眼繭', '病毒感染', '腎及其他泌尿器官之良性腫瘤', '骨膜炎，骨髓炎', '多發性神經炎', '硬腦膜下出血', '麥粒腫', '疤痕攣縮增生', '多汗症', '顱骨骨折', '支氣管炎', '皮膚癌，但第二期（含）以上惡性黑色素瘤除外', '玻璃體病變', '胸痛', '蜘蛛網膜下腔出血', '創傷性血胸，氣胸', '眼附屬器官外傷（眼瞼,眼眶等）', '哮喘，氣喘', '水腦症', '頸，胸，腹部外傷', '頸椎骨折', '中耳積液', '背，臀部外傷', '其他循環系統疾病', '陰囊水腫', '脾臟疾病', '淚器系疾患', '帶狀皰疹', '紅斑性狼瘡', '咽炎/會厭炎', '扁桃體及腺樣體之慢性疾病', '結膜之疾患', '痙攣,抽搐', '生殖器外傷', '外耳炎', '脊椎（髓）炎', '髖及大腿之外傷', '青光眼', '其他病毒性疾病', '何杰金氏症', '其他內分泌腺之良性腫瘤', '氣胸', '淋巴管炎', '乳房疾病', '睪丸炎，副睪丸炎', '睪丸惡性腫瘤', '其他先天性畸形', '藥癮', '急性上呼吸道感染', '斜視及其他雙眼運動之疾患', '精神官能症', '不明熱', '臉，頭，頸部', '眼瞼之疾患（發炎,眼瞼內外翻,睫毛倒插等）', '耳前（後）廔管', '濕疹', '便秘', '腦挫傷', '脊椎側彎（彎曲）症', '其他心臟及循環系統之先天畸形', '隱睪症', '幽門，賁門病變', '毛囊炎', '倦怠及肢體無力', '血糖過低', '急性中耳炎及急性乳突炎', '川崎症', '玫瑰疹', '腸系膜炎', '心室，心房中膈缺損', '其他細菌性疾病', '熱性痙攣', '尿道下裂及上裂', '腸套疊', '腸粘黏', '其他血液及造血器官疾病', '卵巢，子宮及其他附屬器官之惡性腫瘤', '動靜脈廔管', '排尿障礙（尿崩,尿漏,頻尿,困難失禁）', '子宮疾患（發炎,粘連,出血,肥大,後屈,糜爛等）', '多發性硬化症', '女性生殖器官良性腫瘤', '痤瘡，疥瘡，褥瘡', '血尿', '乳房良性腫瘤', '陰道,陰唇,外陰疾病（發炎,膿腫,出血等）', '排經異常（經痛,過期等）', '膀胱炎', '其他懷孕，生產及產褥之合併症', '治療性流產', '醫療行為必要之剖腹產', '子宮外孕', '其他女性生殖器官疾病', '骨盆腔疾病（發炎,粘連,出血等）', '子宮內膜異位(卵巢巧克力囊腫或其他部位之異位)', '葡萄胎', '巴氏腺囊腫，巴氏腺膿瘍', '早產兒/低體重兒', '腦膜及中樞神經系統結核病', '肌無力', '肝功能異常', '懷孕毒血症，子癇前兆症，子癇症', '美尼爾氏病', '視路及視神經之疾患', '自然生產', '前置胎盤', '輸卵管,卵巢疾病（發炎，粘連，功能不良等）', '胸（肋）膜炎，積水', '先兆性流產', '急性喉炎及氣管炎', '登革熱', '高脂蛋白血症', '急性鼻竇炎', '一般剖腹產', '聲帶炎，失音', '其他腦神經損傷', '胃腸不適', '坐骨神經痛', '腮腺炎', '中暑', '進行性痴呆症', '白血球缺少症', '虹彩炎', '肺水腫', '心包膜炎', '肺沉著症及外因所致之肺疾病', '耳鳴，重聽', '診斷欠明之腸道傳染', '二尖瓣，三尖瓣狹窄，閉鎖不全', '傳導阻礙', '卵巢邊緣性癌症', '產後大出血', '在 ...
# 419

# %%
#客戶
tenure = list(df["TENURE"])
tenure_x = ["<5","5~10","10~15","15~20","20~25",">25"]
tenure_count =[0,0,0,0,0,0]

money_spend = list(df["Sum_afyp_K"])##付的保費
money_spend_total = [0,0,0,0,0,0]

money_within_5 = list(df["REIMB_AMT_5Y_K"]) ##理賠金額
money_total = [0,0,0,0,0,0]


for i in range(len(tenure)):

    num = tenure[i]
    dollar_cost =  money_within_5[i]
    dollar_spend = money_spend[i]
    tenure_catg = -1
    if(num<5):
        tenure_catg = 0
    elif(num>=5 and num<10):
        tenure_catg = 1
    elif(num>=10 and num<15):
        tenure_catg = 2
    elif(num>=15 and num<20):
        tenure_catg = 3
    elif(num>=20 and num<25):
        tenure_catg = 4
    elif(num>=25):
        tenure_catg = 5
        
    tenure_count[tenure_catg]+=1
    money_total[tenure_catg] += dollar_cost
    money_spend_total[tenure_catg] += dollar_spend

for i in range(len(tenure_count)):
    money_total[i] = money_total[i]/tenure_count[i]
    money_spend_total[i] = money_spend_total[i]/tenure_count[i]
    

print(money_total)
print(money_spend_total)
    
##客戶年資-人數
nrows = 1
ncols = 2
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(nrows, ncols, 1)
ax.bar(tenure_x,tenure_count)

ax = fig.add_subplot(nrows, ncols, 2)
ax.pie(tenure_count, labels=tenure_x, autopct='%1.1f%%')
# Out:
# [32.03657234383342, 106.15921173885305, 151.95054181717143, 200.21643797353445, 203.1299650852331, 216.62439331296062]
# [68.03250133475707, 97.0021974906075, 117.55050013892748, 134.3592751649733, 163.97831176833026, 205.3665288513392]
# ([<matplotlib.patches.Wedge at 0x118191080>,
#   <matplotlib.patches.Wedge at 0x118191780>,
#   <matplotlib.patches.Wedge at 0x118191e80>,
#   <matplotlib.patches.Wedge at 0x1183285c0>,
#   <matplotlib.patches.Wedge at 0x118328cc0>,
#   <matplotlib.patches.Wedge at 0x118320400>],
#  [Text(0.9963991097533607, 0.4660352069132874, '<5'),
#   Text(0.3081418407542271, 1.0559586194432984, '5~10'),
#   Text(-0.5733423217331831, 0.9387643911597858, '10~15'),
#   Text(-1.0700098693499522, -0.2551056241906444, '15~20'),
#   Text(0.22962124964616912, -1.0757667413110203, '20~25'),
#   Text(1.042469075105797, -0.3510815111168122, '>25')],
#  [Text(0.543490423501833, 0.2542010219527022, '13.9%'),
#   Text(0.16807736768412387, 0.5759774287872537, '13.1%'),
#   Text(-0.31273217549082716, 0.512053304268974, '13.4%'),
#   Text(-0.5836417469181557, -0.13914852228580604, '26.6%'),
#   Text(0.12524795435245586, -0.5867818588969201, '22.6%'),
#   Text(0.5686194955122529, -0.1914990060637157, '10.3%')])

# %%
##客戶年資 - 購買保單金額
nrows = 1
ncols = 2
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(nrows, ncols, 1)
ax.bar(xlabel,money_spend_total)
#購賣保單金額，隨著年資增長而提高

ax = fig.add_subplot(nrows, ncols, 2)
ax.pie(money_spend_total, labels=xlabel, autopct='%1.1f%%')
#年資20年以上，佔了保單金額約五成
# Out:
# ([<matplotlib.patches.Wedge at 0x121c164a8>,
#   <matplotlib.patches.Wedge at 0x121c16ba8>,
#   <matplotlib.patches.Wedge at 0x121c1e2e8>,
#   <matplotlib.patches.Wedge at 0x121c1e9e8>,
#   <matplotlib.patches.Wedge at 0x121c29128>,
#   <matplotlib.patches.Wedge at 0x121c29828>],
#  [Text(1.059611768051951, 0.2953352349548198, '<5'),
#   Text(0.6565480068659527, 0.8825784467571963, '5~10'),
#   Text(-0.2375335065256616, 1.074047407369723, '10~15'),
#   Text(-1.0345695196301479, 0.373719024204342, '15~20'),
#   Text(-0.7298142801304441, -0.8230255867940448, '20~25'),
#   Text(0.7500128487881985, -0.8046618710070779, '>25')],
#  [Text(0.5779700553010642, 0.16109194633899257, '8.7%'),
#   Text(0.35811709465415603, 0.4814064255039252, '12.3%'),
#   Text(-0.12956373083217904, 0.5858440403834851, '15.0%'),
#   Text(-0.5643106470709897, 0.2038467404750956, '17.1%'),
#   Text(-0.39808051643478765, -0.4489230473422062, '20.9%'),
#   Text(0.4090979175208355, -0.4389064750947697, '26.1%')])

# %%
nrows = 1
ncols = 2
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(nrows, ncols, 1)
ax.bar(xlabel,money_total)
#年資越高，五年內平均理賠金額越高   

ax = fig.add_subplot(nrows, ncols, 2)
ax.pie(money_total, labels=xlabel, autopct='%1.1f%%')
#年資15年以上，理賠金額佔百分之七十
# Out:
# ([<matplotlib.patches.Wedge at 0x11d794a58>,
#   <matplotlib.patches.Wedge at 0x11d79c198>,
#   <matplotlib.patches.Wedge at 0x11d79c898>,
#   <matplotlib.patches.Wedge at 0x11d79cf98>,
#   <matplotlib.patches.Wedge at 0x11d76c6d8>,
#   <matplotlib.patches.Wedge at 0x11d76cdd8>],
#  [Text(1.0932808048103144, 0.1213963831146189, '<5'),
#   Text(0.9154902687989155, 0.6098176512159103, '5~10'),
#   Text(0.1012997272753174, 1.0953256891235348, '10~15'),
#   Text(-0.991738101169652, 0.4758734481859786, '15~20'),
#   Text(-0.6444016401701875, -0.8914855725955256, '20~25'),
#   Text(0.8065381845717912, -0.7479947572193535, '>25')],
#  [Text(0.5963349844419896, 0.06621620897161029, '3.5%'),
#   Text(0.49935832843577205, 0.33262780975413286, '11.7%'),
#   Text(0.055254396695627664, 0.5974503758855644, '16.7%'),
#   Text(-0.5409480551834465, 0.25956733537417015, '22.0%'),
#   Text(-0.3514918037291932, -0.48626485777937756, '22.3%'),
#   Text(0.43992991885734056, -0.4079971403014655, '23.8%')])
