# %%
# %matplotlib inline
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv



dict={}
data_list = []
# 開啟 CSV 檔案
with open('claim.csv', newline='') as csvfile:
    

  # 讀取 CSV 檔案內容
    data_list = list(csv.reader(csvfile))
    print(data_list[2])
 

  # 以迴圈輸出每一列
#     for row in data_list[2:10]:
        
#         list.append(row)
    
#     print(data_list[0][0:5])
            
    
# dict['病名'][0:100]
# list[6]
# Out:
# ['2', 'M', '03.41~60', '16', 'A27902', '冠狀動脈疾病', 'UM0011', '新光醫院', '18', '2017/3/3', '3', '71', '16', '2', '23', '', '', '']

# %%
print('h')
# Out:
# h

# %%
claim = []
##style 
plt.style.use('classic')
plt.plot([1,5,3,4],'ro')
plt.bar([1,2,3,4],[1,5,3,4])
plt.xlabel('x label')
plt.ylabel('y label')

fig,ax = plt.subplots()
ax.plot([1,8,3,4],[1,2,3,4],lw = 2, color = '#539caf', alpha = 1)


# with open("claim.csv", 'r') as csvFile:
#     rows = csv.reader(csvFile)

#     row_num = 0
#     for i in rows:
#         claim.append(i)

# for i in claim:
#     print(i[4])


# ill = {}

# for i in claim:
#     if i[4] not in ill:
#         ill[str(i[4])] = 1

#     else:
#         ill[str(i[4])] += 1

# print(ill)
